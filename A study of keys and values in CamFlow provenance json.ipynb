# %%
import collections
import json
import codecs
from pprint import pprint

# %%
def nested_dict_iter(nested):
    for key, value in nested.items():
        if isinstance(value, collections.Mapping):
            for inner_key, inner_value in nested_dict_iter(value):
                yield inner_key, inner_value
        else:
            yield key, value

def printSendersAndReceivers(s,r):
    print("Senders:")
    for e in s: print(e)
    print()
    print("Receivers:")
    for e in r: print(e)
        
def getAllSenderAndReceiverEntities(jsonobj):
    senders,receivers = set(),set()
    for key,value in nested_dict_iter(jsonobj):
        if key == 'cf:sender':
            senders.add(value)
        elif key == 'cf:receiver':
            receivers.add(value)
    return senders,receivers

def getAllValuesForKey(k,nested):
    for key, value in nested.items():
        if k == key:
            yield value
        if isinstance(value, collections.Mapping):
            for inner_key, inner_value in nested_dict_iter(value):
                if inner_key == k:
                    yield inner_value
                
def getAllKeys(nested):
    for key, value in nested.items():
        if isinstance(value, collections.Mapping):
            yield key
            for inner_key, inner_value in nested_dict_iter(value):
                yield inner_key
        else:
            yield key
            
def getDictImmediatelyEnclosingKeyValue(key1,value1,nested):
    for key, value in nested.items():
        if value1 == value and key1 == key:
            yield "<main dict>"
        if isinstance(value, collections.Mapping):
            for inner_key, inner_value in nested_dict_iter(value):
                if value1 == inner_value and key1 == inner_key:
                    yield {prev_key:prev_val}
                prev_key,prev_val = inner_key,inner_value

# %% [markdown]
# # CamFlow v0.2.0 - The Thomas example where containers are seen in the graph

# %%
d1 = json.load(codecs.open('logs/thomas-container-diff.json', 'r', 'utf-8-sig'))

# %%
s,r = getAllSenderAndReceiverEntities(d1)
printSendersAndReceivers(s,r)
#Note: Both sets are the same below.
# The servers running seem to be 
# Proxy http://10.5.0.3:8081/
# Server: httpd = SocketServer.ForkingTCPServer(('10.5.0.2',PORT), Proxy)
# Out:
# Senders:
# 10.5.0.2:48032
# 10.5.0.1:38442
# 10.5.0.3:8081
# 10.5.0.2:48040
# 10.5.0.2:48036
#
# Receivers:
# 10.5.0.2:48032
# 10.5.0.1:38442
# 10.5.0.3:8081
# 10.5.0.2:48040
# 10.5.0.2:48036

# %%
print("All keys in the json dict:")
pprint(set([v for v in getAllKeys(d1)]))
# Out:
# All keys in the json dict:
# {'activity',
#  'cf',
#  'cf:allowed',
#  'cf:boot_id',
#  'cf:camflow',
#  'cf:cid',
#  'cf:date',
#  'cf:gid',
#  'cf:id',
#  'cf:ino',
#  'cf:jiffies',
#  'cf:machine',
#  'cf:machine_id',
#  'cf:mode',
#  'cf:nodename',
#  'cf:offset',
#  'cf:pathname',
#  'cf:pid',
#  'cf:receiver',
#  'cf:release',
#  'cf:secctx',
#  'cf:sender',
#  'cf:seq',
#  'cf:sysname',
#  'cf:uid',
#  'cf:uuid',
#  'cf:version',
#  'cf:vpid',
#  'entity',
#  'host',
#  'path',
#  'prefix',
#  'prov',
#  'prov:activity',
#  'prov:entity',
#  'prov:generatedEntity',
#  'prov:informant',
#  'prov:informed',
#  'prov:label',
#  'prov:type',
#  'prov:usedEntity',
#  'serv',
#  'type',
#  'used',
#  'wasDerivedFrom',
#  'wasGeneratedBy',
#  'wasInformedBy'}

# %% [markdown]
# ## Let's look at what the standard says about the structure of this json:
# ## [Link to PROV data model spec](https://www.w3.org/TR/prov-dm/ "PROV data model").
#
# ## "At its core, provenance describes the:
# ## *use and production* of **entities**
# ## *by* **activities**,
# ## which may be in various ways *influenced by* **agents**."
#
# ## ![https://www.w3.org/TR/prov-dm/uml/essentials.png](prov-core-structure.png)
#
# ## PROV-N in particular looks helpful because "PROV-N (Recommendation), a notation for provenance aimed at human consumption": https://www.w3.org/TR/2013/REC-prov-n-20130430/
#
# ## Based on this document and eyeballing the json data, we perform some analysis:

# %%
# What are the prov:label and prov:type values in our execution:
print('prov:label values')
pprint(set([v for v in getAllValuesForKey('prov:label',d1)]))
# Out:
# prov:label values
# {'[address] IPV4 10.5.0.3',
#  '[address] UNIX /var/run/nscd/socket',
#  '[fifo] 0',
#  '[file] 0',
#  '[file] 1',
#  '[machine] 1022090165',
#  '[machine] 1030075630',
#  '[machine] 1048856292',
#  '[machine] 1054465990',
#  '[machine] 1100367967',
#  '[machine] 114986689',
#  '[machine] 1237468202',
#  '[machine] 1268947775',
#  '[machine] 1404656863',
#  '[machine] 1480552698',
#  '[machine] 1558345364',
#  '[machine] 1577082000',
#  '[machine] 1941367434',
#  '[machine] 2007545844',
#  '[machine] 289813543',
#  '[machine] 340646718',
#  '[machine] 776556187',
#  '[machine] 81213873',
#  '[machine] 868444599',
#  '[machine] 972296071',
#  '[machine] 973350807',
#  '[mmaped_file] 0',
#  '[packet] 10.5.0.1:38442->10.5.0.3:8081 (2059)',
#  '[packet] 10.5.0.1:38442->10.5.0.3:8081 (2315)',
#  '[packet] 10.5.0.2:48032->10.5.0.3:8081 (33877)',
#  '[packet] 10.5.0.2:48032->10.5.0.3:8081 (34133)',
#  '[packet] 10.5.0.2:48036->10.5.0.3:8081 (32973)',
#  '[packet] 10.5.0.2:48036->10.5.0.3:8081 (33229)',
#  '[packet] 10.5.0.2:48036->10.5.0.3:8081 (33485)',
#  '[packet] 10.5.0.2:48036->10.5.0.3:8081 (33741)',
#  '[packet] 10.5.0.2:48036->10.5.0.3:8081 (33997)',
#  '[packet] 10.5.0.2:48036->10.5.0.3:8081 (34253)',
#  '[packet] 10.5.0.2:48040->10.5.0.3:8081 (13692)',
#  '[packet] 10.5.0.2:48040->10.5.0.3:8081 (13948)',
#  '[packet] 10.5.0.2:48040->10.5.0.3:8081 (14204)',
#  '[packet] 10.5.0.2:48040->10.5.0.3:8081 (14460)',
#  '[packet] 10.5.0.2:48040->10.5.0.3:8081 (14716)',
#  '[packet] 10.5.0.3:8081->10.5.0.1:38442 (33557)',
#  '[packet] 10.5.0.3:8081->10.5.0.1:38442 (33813)',
#  '[packet] 10.5.0.3:8081->10.5.0.1:38442 (34069)',
#  '[packet] 10.5.0.3:8081->10.5.0.2:48032 (14485)',
#  '[packet] 10.5.0.3:8081->10.5.0.2:48032 (14741)',
#  '[packet] 10.5.0.3:8081->10.5.0.2:48032 (14997)',
#  '[packet] 10.5.0.3:8081->10.5.0.2:48036 (0)',
#  '[packet] 10.5.0.3:8081->10.5.0.2:48036 (26436)',
#  '[packet] 10.5.0.3:8081->10.5.0.2:48036 (26692)',
#  '[packet] 10.5.0.3:8081->10.5.0.2:48036 (26948)',
#  '[packet] 10.5.0.3:8081->10.5.0.2:48036 (27204)',
#  '[packet] 10.5.0.3:8081->10.5.0.2:48036 (27460)',
#  '[packet] 10.5.0.3:8081->10.5.0.2:48040 (0)',
#  '[packet] 10.5.0.3:8081->10.5.0.2:48040 (5370)',
#  '[packet] 10.5.0.3:8081->10.5.0.2:48040 (5626)',
#  '[packet] 10.5.0.3:8081->10.5.0.2:48040 (5882)',
#  '[packet] 10.5.0.3:8081->10.5.0.2:48040 (6138)',
#  '[path] /rootfs/etc/host.conf',
#  '[path] /rootfs/etc/nsswitch.conf',
#  '[path] /rootfs/lib/x86_64-linux-gnu/libnss_files-2.19.so',
#  '[path] /rootfs/usr/local/lib/python2.7/httplib.py',
#  '[path] /rootfs/usr/local/lib/python2.7/httplib.pyc',
#  '[path] /rootfs/usr/local/lib/python2.7/lib-dynload/array.so',
#  '[path] '
#  '/rootfs/usr/local/lib/python3.6/__pycache__/stringprep.cpython-36.pyc.140355802449152',
#  '[path] '
#  '/rootfs/usr/local/lib/python3.6/encodings/__pycache__/idna.cpython-36.pyc.140355802466584',
#  '[path] /rootfs/usr/local/lib/python3.6/encodings/idna.py',
#  '[path] '
#  '/rootfs/usr/local/lib/python3.6/lib-dynload/unicodedata.cpython-36m-x86_64-linux-gnu.so',
#  '[path] /rootfs/usr/local/lib/python3.6/stringprep.py',
#  '[path] /usr/local/bin/python2.7',
#  '[path] /usr/local/bin/python3.6',
#  '[socket] 0',
#  '[socket] 1',
#  '[socket] 2',
#  '[socket] 3',
#  '[socket] 4',
#  '[socket] 5',
#  '[socket] 6',
#  '[socket] 7',
#  '[task] 0',
#  '[task] 1',
#  '[task] 10',
#  '[task] 11',
#  '[task] 12',
#  '[task] 13',
#  '[task] 14',
#  '[task] 2',
#  '[task] 3',
#  '[task] 4',
#  '[task] 5',
#  '[task] 6',
#  '[task] 7',
#  '[task] 8',
#  '[task] 9',
#  'accept',
#  'clone',
#  'connect',
#  'create',
#  'getattr',
#  'link',
#  'mmap',
#  'mmap_exec',
#  'mmap_read',
#  'mmap_write',
#  'named_process',
#  'open',
#  'perm_read',
#  'read',
#  'receive',
#  'receive_packet',
#  'send',
#  'send_packet',
#  'unknown',
#  'version_activity',
#  'version_entity',
#  'write'}

# %%
print('prov:type values')
pprint(set([v for v in getAllValuesForKey('prov:type',d1)]))
# Out:
# prov:type values
# {'accept',
#  'address',
#  'clone',
#  'connect',
#  'create',
#  'fifo',
#  'file',
#  'file_name',
#  'getattr',
#  'link',
#  'mmap',
#  'mmap_exec',
#  'mmap_read',
#  'mmap_write',
#  'mmaped_file',
#  'named_process',
#  'open',
#  'packet',
#  'perm_read',
#  'read',
#  'receive',
#  'receive_packet',
#  'send',
#  'send_packet',
#  'socket',
#  'task',
#  'unknown',
#  'version_activity',
#  'version_entity',
#  'write'}

# %% [markdown]
# ## First hypothesis: in a communication between one container and the other, the entities are packets.
#
# ## Why is this helpful? If this is true, one way of reducing the graph is by reducing entities that correspond to packets

# %%
#Test the hypothesis that packets are entities:
#Hypothesis: some or all of the keys: (entity, prov:entity, type) can be indicative of whether a provenance
#  entry is about an entity
#Experiment: Check the output of all values that belong to these keys

# %%
pprint([v for v in getAllValuesForKey('entity',d1)])
# There's too much data here to be able to discern anything meaningful
# Out:
# [{'1022090165': {'cf:camflow': 'v0.2.0',
#                  'cf:date': '2017:01:30T04:47:06',
#                  'cf:machine': 'x86_64',
#                  'cf:nodename': 'machine6',
#                  'cf:release': '4.9.5',
#                  'cf:sysname': 'Linux',
#                  'cf:version': '#1 SMP Wed Jan 25 05:52:47 UTC 2017',
#                  'prov:label': '[machine] 1022090165'},
#   '1030075630': {'cf:camflow': 'v0.2.0',
#                  'cf:date': '2017:01:25T01:39:32',
#                  'cf:machine': 'x86_64',
#                  'cf:nodename': 'machine2',
#                  'cf:release': '4.9.5',
#                  'cf:sysname': 'Linux',
#                  'cf:version': '#1 SMP Wed Jan 25 01:33:54 UTC 2017',
#                  'prov:label': '[machine] 1030075630'},
#   '1048856292': {'cf:camflow': 'v0.2.1',
#                  'cf:date': '2017:02:01T00:50:51',
#                  'cf:machine': 'x86_64',
#                  'cf:nodename': 'localhost.localdomain',
#                  'cf:release': '4.9.5',
#                  'cf:sysname': 'Linux',
#                  'cf:version': '#8 SMP Thu Jan 26 13:19:57 CET 2017',
#                  'prov:label': '[machine] 1048856292'},
#   '1054465990': {'cf:camflow': 'v0.2.1',
#                  'cf:date': '2017:02:08T01:19:36',
#                  'cf:machine': 'x86_64',
#                  'cf:nodename': 'localhost.localdomain',
#                  'cf:release': '4.9.5',
#                  'cf:sysname': 'Linux',
#                  'cf:version': '#1 SMP Fri Feb 3 23:29:02 UTC 2017',
#                  'prov:label': '[machine] 1054465990'},
#   '1100367967': {'cf:camflow': 'v0.2.0',
#                  'cf:date': '2017:01:25T12:24:16',
#                  'cf:machine': 'x86_64',
#                  'cf:nodename': 'localhost.localdomain',
#                  'cf:release': '4.9.5',
#                  'cf:sysname': 'Linux',
#                  'cf:version': '#1 SMP Tue Jan 24 00:55:02 UTC 2017',
#                  'prov:label': '[machine] 1100367967'},
#   '114986689': {'cf:camflow': 'v0.2.0',
#                 'cf:date': '2017:01:25T05:30:05',
#                 'cf:machine': 'x86_64',
#                 'cf:nodename': 'machine5',
#                 'cf:release': '4.9.5',
#                 'cf:sysname': 'Linux',
#                 'cf:version': '#1 SMP Wed Jan 25 05:27:42 UTC 2017',
#                 'prov:label': '[machine] 114986689'},
#   '1237468202': {'cf:camflow': 'v0.2.2',
#                  'cf:date': '2017:02:10T14:50:09',
#                  'cf:machine': 'x86_64',
#                  'cf:nodename': 'localhost.localdomain',
#                  'cf:release': '4.9.8',
#                  'cf:sysname': 'Linux',
#                  'cf:version': '#1 SMP Fri Feb 10 13:16:33 CET 2017',
#                  'prov:label': '[machine] 1237468202'},
#   '1268947775': {'cf:camflow': 'v0.2.0',
#                  'cf:date': '2017:01:29T18:48:21',
#                  'cf:machine': 'x86_64',
#                  'cf:nodename': 'machine3',
#                  'cf:release': '4.9.5',
#                  'cf:sysname': 'Linux',
#                  'cf:version': '#1 SMP Wed Jan 25 02:28:19 UTC 2017',
#                  'prov:label': '[machine] 1268947775'},
#   '1404656863': {'cf:camflow': 'v0.2.1',
#                  'cf:date': '2017:02:10T10:32:35',
#                  'cf:machine': 'x86_64',
#                  'cf:nodename': 'localhost.localdomain',
#                  'cf:release': '4.9.5',
#                  'cf:sysname': 'Linux',
#                  'cf:version': '#1 SMP Fri Feb 10 10:05:02 UTC 2017',
#                  'prov:label': '[machine] 1404656863'},
#   '1480552698': {'cf:camflow': 'v0.2.0',
#                  'cf:date': '2017:01:23T22:54:27',
#                  'cf:machine': 'x86_64',
#                  'cf:nodename': 'localhost.localdomain',
#                  'cf:release': '4.9.5',
#                  'cf:sysname': 'Linux',
#                  'cf:version': '#1 SMP Mon Jan 23 22:06:19 UTC 2017',
#                  'prov:label': '[machine] 1480552698'},
#   '1558345364': {'cf:camflow': 'v0.2.0',
#                  'cf:date': '2017:01:30T03:04:45',
#                  'cf:machine': 'x86_64',
#                  'cf:nodename': 'machine4',
#                  'cf:release': '4.9.5',
#                  'cf:sysname': 'Linux',
#                  'cf:version': '#1 SMP Wed Jan 25 04:41:05 UTC 2017',
#                  'prov:label': '[machine] 1558345364'},
#   '1577082000': {'cf:camflow': 'v0.1.11',
#                  'cf:date': '2016:12:30T20:53:18',
#                  'cf:machine': 'x86_64',
#                  'cf:nodename': 'localhost.localdomain',
#                  'cf:release': '4.4.36',
#                  'cf:sysname': 'Linux',
#                  'cf:version': '#1 SMP Fri Dec 30 20:49:36 UTC 2016',
#                  'prov:label': '[machine] 1577082000'},
#   '1941367434': {'cf:camflow': 'v0.2.0',
#                  'cf:date': '2017:01:27T01:57:07',
#                  'cf:machine': 'x86_64',
#                  'cf:nodename': 'machine8',
#                  'cf:release': '4.9.5',
#                  'cf:sysname': 'Linux',
#                  'cf:version': '#1 SMP Thu Jan 26 17:54:18 PST 2017',
#                  'prov:label': '[machine] 1941367434'},
#   '2007545844': {'cf:camflow': 'v0.1.12',
#                  'cf:date': '2016:12:09T16:10:11',
#                  'cf:machine': 'x86_64',
#                  'cf:nodename': 'uiswhwks261400b.university.harvard.edu',
#                  'cf:release': '4.4.36',
#                  'cf:sysname': 'Linux',
#                  'cf:version': '#2 SMP Tue Dec 6 17:38:11 PST 2016',
#                  'prov:label': '[machine] 2007545844'},
#   '289813543': {'cf:camflow': 'v0.2.0',
#                 'cf:date': '2017:01:23T22:12:23',
#                 'cf:machine': 'x86_64',
#                 'cf:nodename': 'localhost.localdomain',
#                 'cf:release': '4.9.5',
#                 'cf:sysname': 'Linux',
#                 'cf:version': '#1 SMP Mon Jan 23 21:48:53 CET 2017',
#                 'prov:label': '[machine] 289813543'},
#   '340646718': {'cf:camflow': 'v0.2.0',
#                 'cf:date': '2017:01:20T14:30:32',
#                 'cf:machine': 'x86_64',
#                 'cf:nodename': 'uiswhwks4013003.university.harvard.edu',
#                 'cf:release': '4.9.5',
#                 'cf:sysname': 'Linux',
#                 'cf:version': '#1 SMP Fri Jan 20 05:51:59 PST 2017',
#                 'prov:label': '[machine] 340646718'},
#   '776556187': {'cf:camflow': 'v0.2.0',
#                 'cf:date': '2017:01:30T04:47:36',
#                 'cf:machine': 'x86_64',
#                 'cf:nodename': 'machine7',
#                 'cf:release': '4.9.5',
#                 'cf:sysname': 'Linux',
#                 'cf:version': '#1 SMP Wed Jan 25 06:43:14 UTC 2017',
#                 'prov:label': '[machine] 776556187'},
#   '81213873': {'cf:camflow': 'v0.2.0',
#                'cf:date': '2017:01:24T20:20:07',
#                'cf:machine': 'x86_64',
#                'cf:nodename': 'machine1',
#                'cf:release': '4.9.5',
#                'cf:sysname': 'Linux',
#                'cf:version': '#1 SMP Tue Jan 24 16:27:08 UTC 2017',
#                'prov:label': '[machine] 81213873'},
#   '868444599': {'cf:camflow': 'v0.2.2',
#                 'cf:date': '2017:02:10T02:18:19',
#                 'cf:machine': 'x86_64',
#                 'cf:nodename': 'localhost.localdomain',
#                 'cf:release': '4.9.8',
#                 'cf:sysname': 'Linux',
#                 'cf:version': '#14 SMP Wed Feb 8 21:17:12 CET 2017',
#                 'prov:label': '[machine] 868444599'},
#   '972296071': {'cf:camflow': 'v0.2.0',
#                 'cf:date': '2017:01:24T21:30:34',
#                 'cf:machine': 'x86_64',
#                 'cf:nodename': 'machine1',
#                 'cf:release': '4.9.5',
#                 'cf:sysname': 'Linux',
#                 'cf:version': '#1 SMP Tue Jan 24 21:04:58 UTC 2017',
#                 'prov:label': '[machine] 972296071'},
#   '973350807': {'cf:camflow': 'v0.2.0',
#                 'cf:date': '2017:01:30T04:46:42',
#                 'cf:machine': 'x86_64',
#                 'cf:nodename': 'machine5',
#                 'cf:release': '4.9.5',
#                 'cf:sysname': 'Linux',
#                 'cf:version': '#1 SMP Sun Jan 29 04:34:43 UTC 2017',
#                 'prov:label': '[machine] 973350807'},
#   'AAACAAAAACAnJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:address': {'path': '/var/run/nscd/socket',
#                                                                   'type': 'AF_UNIX'},
#                                                    'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:26',
#                                                    'cf:id': '75559',
#                                                    'cf:jiffies': '4294765349',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:version': 0,
#                                                    'prov:label': '[address] '
#                                                                  'UNIX '
#                                                                  '/var/run/nscd/socket',
#                                                    'prov:type': 'address'},
#   'AAACAAAAACCTNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:address': {'host': '10.5.0.3',
#                                                                   'serv': 'tproxy',
#                                                                   'type': 'AF_INET'},
#                                                    'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:38',
#                                                    'cf:id': '79251',
#                                                    'cf:jiffies': '4294957786',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:version': 0,
#                                                    'prov:label': '[address] '
#                                                                  'IPV4 '
#                                                                  '10.5.0.3',
#                                                    'prov:type': 'address'},
#   'AAAIAAAAACAXJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:26',
#                                                    'cf:id': '75543',
#                                                    'cf:jiffies': '4294765276',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/usr/local/bin/python3.6',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/usr/local/bin/python3.6',
#                                                    'prov:type': 'file_name'},
#   'AAAIAAAAACAYJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:26',
#                                                    'cf:id': '75544',
#                                                    'cf:jiffies': '4294765277',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/rootfs/usr/local/lib/python3.6/encodings/idna.py',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/rootfs/usr/local/lib/python3.6/encodings/idna.py',
#                                                    'prov:type': 'file_name'},
#   'AAAIAAAAACAaJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:26',
#                                                    'cf:id': '75546',
#                                                    'cf:jiffies': '4294765301',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/rootfs/usr/local/lib/python3.6/encodings/__pycache__/idna.cpython-36.pyc.140355802466584',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/rootfs/usr/local/lib/python3.6/encodings/__pycache__/idna.cpython-36.pyc.140355802466584',
#                                                    'prov:type': 'file_name'},
#   'AAAIAAAAACAcJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:26',
#                                                    'cf:id': '75548',
#                                                    'cf:jiffies': '4294765302',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/rootfs/usr/local/lib/python3.6/stringprep.py',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/rootfs/usr/local/lib/python3.6/stringprep.py',
#                                                    'prov:type': 'file_name'},
#   'AAAIAAAAACAeJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:26',
#                                                    'cf:id': '75550',
#                                                    'cf:jiffies': '4294765302',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/rootfs/usr/local/lib/python3.6/__pycache__/stringprep.cpython-36.pyc.140355802449152',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/rootfs/usr/local/lib/python3.6/__pycache__/stringprep.cpython-36.pyc.140355802449152',
#                                                    'prov:type': 'file_name'},
#   'AAAIAAAAACAgJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:26',
#                                                    'cf:id': '75552',
#                                                    'cf:jiffies': '4294765305',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/rootfs/usr/local/lib/python3.6/lib-dynload/unicodedata.cpython-36m-x86_64-linux-gnu.so',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/rootfs/usr/local/lib/python3.6/lib-dynload/unicodedata.cpython-36m-x86_64-linux-gnu.so',
#                                                    'prov:type': 'file_name'},
#   'AAAIAAAAACApJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:26',
#                                                    'cf:id': '75561',
#                                                    'cf:jiffies': '4294765350',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/rootfs/etc/nsswitch.conf',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/rootfs/etc/nsswitch.conf',
#                                                    'prov:type': 'file_name'},
#   'AAAIAAAAACAsJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:26',
#                                                    'cf:id': '75564',
#                                                    'cf:jiffies': '4294765359',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/usr/local/bin/python3.6',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/usr/local/bin/python3.6',
#                                                    'prov:type': 'file_name'},
#   'AAAIAAAAACAvJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:26',
#                                                    'cf:id': '75567',
#                                                    'cf:jiffies': '4294765359',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/rootfs/lib/x86_64-linux-gnu/libnss_files-2.19.so',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/rootfs/lib/x86_64-linux-gnu/libnss_files-2.19.so',
#                                                    'prov:type': 'file_name'},
#   'AAAIAAAAACAzJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:26',
#                                                    'cf:id': '75571',
#                                                    'cf:jiffies': '4294765371',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/rootfs/etc/host.conf',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/rootfs/etc/host.conf',
#                                                    'prov:type': 'file_name'},
#   'AAAIAAAAACB2NQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:34',
#                                                    'cf:id': '79222',
#                                                    'cf:jiffies': '4294954256',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/usr/local/bin/python2.7',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/usr/local/bin/python2.7',
#                                                    'prov:type': 'file_name'},
#   'AAAIAAAAACB5NQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:34',
#                                                    'cf:id': '79225',
#                                                    'cf:jiffies': '4294954258',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/rootfs/usr/local/lib/python2.7/httplib.pyc',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/rootfs/usr/local/lib/python2.7/httplib.pyc',
#                                                    'prov:type': 'file_name'},
#   'AAAIAAAAACB7NQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:34',
#                                                    'cf:id': '79227',
#                                                    'cf:jiffies': '4294954266',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/rootfs/usr/local/lib/python2.7/lib-dynload/array.so',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/rootfs/usr/local/lib/python2.7/lib-dynload/array.so',
#                                                    'prov:type': 'file_name'},
#   'AAAIAAAAACCONQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:38',
#                                                    'cf:id': '79246',
#                                                    'cf:jiffies': '4294957786',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/usr/local/bin/python2.7',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/usr/local/bin/python2.7',
#                                                    'prov:type': 'file_name'},
#   'AAAIAAAAACCPNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:38',
#                                                    'cf:id': '79247',
#                                                    'cf:jiffies': '4294957786',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:pathname': '/rootfs/usr/local/lib/python2.7/httplib.py',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[path] '
#                                                                  '/rootfs/usr/local/lib/python2.7/httplib.py',
#                                                    'prov:type': 'file_name'},
#   'AAAQAAAAACAAAAAACgUAAwoFAAIfkbukBgAAAI8Jnrw=': {'cf:id': 0,
#                                                    'cf:jiffies': '4294957786',
#                                                    'cf:receiver': '10.5.0.2:48036',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 3164473743,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.2:48036 '
#                                                                  '(0)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACAAAAAACgUAAwoFAAIfkbuoBgAAAELEJXU=': {'cf:id': 0,
#                                                    'cf:jiffies': '4294958946',
#                                                    'cf:receiver': '10.5.0.2:48040',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 1965409346,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.2:48040 '
#                                                                  '(0)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACALCAAACgUAAQoFAAOWKh+RBgAAACmAvK8=': {'cf:id': 2059,
#                                                    'cf:jiffies': '4294948645',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.1:38442',
#                                                    'cf:seq': 2948366377,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.1:38442->10.5.0.3:8081 '
#                                                                  '(2059)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACALCQAACgUAAQoFAAOWKh+RBgAAACmAvK8=': {'cf:id': 2315,
#                                                    'cf:jiffies': '4294948645',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.1:38442',
#                                                    'cf:seq': 2948366377,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.1:38442->10.5.0.3:8081 '
#                                                                  '(2315)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACAVgwAACgUAAwoFAAEfkZYqBgAAAOaWoqM=': {'cf:id': 33557,
#                                                    'cf:jiffies': '4294948645',
#                                                    'cf:receiver': '10.5.0.1:38442',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 2745341670,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.1:38442 '
#                                                                  '(33557)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACAVhAAACgUAAwoFAAEfkZYqBgAAAOaWoxc=': {'cf:id': 33813,
#                                                    'cf:jiffies': '4294948645',
#                                                    'cf:receiver': '10.5.0.1:38442',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 396596966,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.1:38442 '
#                                                                  '(33813)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACAVhQAACgUAAwoFAAEfkZYqBgAAAOaWoyg=': {'cf:id': 34069,
#                                                    'cf:jiffies': '4294948645',
#                                                    'cf:receiver': '10.5.0.1:38442',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 681809638,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.1:38442 '
#                                                                  '(34069)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACB8NQAACgUAAgoFAAO7qB+RBgAAAHuFo1c=': {'cf:id': 13692,
#                                                    'cf:jiffies': '4294958946',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.2:48040',
#                                                    'cf:seq': 1470334331,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.2:48040->10.5.0.3:8081 '
#                                                                  '(13692)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACB8NgAACgUAAgoFAAO7qB+RBgAAAHuFo1g=': {'cf:id': 13948,
#                                                    'cf:jiffies': '4294958946',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.2:48040',
#                                                    'cf:seq': 1487111547,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.2:48040->10.5.0.3:8081 '
#                                                                  '(13948)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACB8NwAACgUAAgoFAAO7qB+RBgAAAHuFo1g=': {'cf:id': 14204,
#                                                    'cf:jiffies': '4294958946',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.2:48040',
#                                                    'cf:seq': 1487111547,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.2:48040->10.5.0.3:8081 '
#                                                                  '(14204)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACB8OAAACgUAAgoFAAO7qB+RBgAAAHuFo6w=': {'cf:id': 14460,
#                                                    'cf:jiffies': '4294958946',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.2:48040',
#                                                    'cf:seq': 2896397691,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.2:48040->10.5.0.3:8081 '
#                                                                  '(14460)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACB8OQAACgUAAgoFAAO7qB+RBgAAAHuFo6w=': {'cf:id': 14716,
#                                                    'cf:jiffies': '4294958946',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.2:48040',
#                                                    'cf:seq': 2896397691,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.2:48040->10.5.0.3:8081 '
#                                                                  '(14716)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACBEZwAACgUAAwoFAAIfkbukBgAAAI8Jnr0=': {'cf:id': 26436,
#                                                    'cf:jiffies': '4294957796',
#                                                    'cf:receiver': '10.5.0.2:48036',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 3181250959,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.2:48036 '
#                                                                  '(26436)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACBEaAAACgUAAwoFAAIfkbukBgAAAI8Jnr0=': {'cf:id': 26692,
#                                                    'cf:jiffies': '4294957796',
#                                                    'cf:receiver': '10.5.0.2:48036',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 3181250959,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.2:48036 '
#                                                                  '(26692)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACBEaQAACgUAAwoFAAIfkbukBgAAAI8JnzE=': {'cf:id': 26948,
#                                                    'cf:jiffies': '4294957796',
#                                                    'cf:receiver': '10.5.0.2:48036',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 832506255,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.2:48036 '
#                                                                  '(26948)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACBEagAACgUAAwoFAAIfkbukBgAAAI8Jn0I=': {'cf:id': 27204,
#                                                    'cf:jiffies': '4294957796',
#                                                    'cf:receiver': '10.5.0.2:48036',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 1117718927,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.2:48036 '
#                                                                  '(27204)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACBEawAACgUAAwoFAAIfkbukBgAAAI8Jn0M=': {'cf:id': 27460,
#                                                    'cf:jiffies': '4294957808',
#                                                    'cf:receiver': '10.5.0.2:48036',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 1134496143,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.2:48036 '
#                                                                  '(27460)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACBVhAAACgUAAgoFAAO7oB+RBgAAAKBSmQc=': {'cf:id': 33877,
#                                                    'cf:jiffies': '4294954293',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.2:48032',
#                                                    'cf:seq': 127488672,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.2:48032->10.5.0.3:8081 '
#                                                                  '(33877)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACBVhQAACgUAAgoFAAO7oB+RBgAAAKBSmQc=': {'cf:id': 34133,
#                                                    'cf:jiffies': '4294954293',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.2:48032',
#                                                    'cf:seq': 127488672,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.2:48032->10.5.0.3:8081 '
#                                                                  '(34133)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACCVOAAACgUAAwoFAAIfkbugBgAAAKxcWAQ=': {'cf:id': 14485,
#                                                    'cf:jiffies': '4294954293',
#                                                    'cf:receiver': '10.5.0.2:48032',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 72899756,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.2:48032 '
#                                                                  '(14485)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACCVOQAACgUAAwoFAAIfkbugBgAAAKxcWHg=': {'cf:id': 14741,
#                                                    'cf:jiffies': '4294954293',
#                                                    'cf:receiver': '10.5.0.2:48032',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 2019056812,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.2:48032 '
#                                                                  '(14741)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACCVOgAACgUAAwoFAAIfkbugBgAAAKxcWIk=': {'cf:id': 14997,
#                                                    'cf:jiffies': '4294954293',
#                                                    'cf:receiver': '10.5.0.2:48032',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 2304269484,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.2:48032 '
#                                                                  '(14997)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACD6FAAACgUAAwoFAAIfkbuoBgAAAELEJXY=': {'cf:id': 5370,
#                                                    'cf:jiffies': '4294958946',
#                                                    'cf:receiver': '10.5.0.2:48040',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 1982186562,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.2:48040 '
#                                                                  '(5370)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACD6FQAACgUAAwoFAAIfkbuoBgAAAELEJXY=': {'cf:id': 5626,
#                                                    'cf:jiffies': '4294958946',
#                                                    'cf:receiver': '10.5.0.2:48040',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 1982186562,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.2:48040 '
#                                                                  '(5626)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACD6FgAACgUAAwoFAAIfkbuoBgAAAELEJeo=': {'cf:id': 5882,
#                                                    'cf:jiffies': '4294958946',
#                                                    'cf:receiver': '10.5.0.2:48040',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 3928343618,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.2:48040 '
#                                                                  '(5882)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACD6FwAACgUAAwoFAAIfkbuoBgAAAELEJfs=': {'cf:id': 6138,
#                                                    'cf:jiffies': '4294958946',
#                                                    'cf:receiver': '10.5.0.2:48040',
#                                                    'cf:sender': '10.5.0.3:8081',
#                                                    'cf:seq': 4213556290,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.3:8081->10.5.0.2:48040 '
#                                                                  '(6138)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACDNgAAACgUAAgoFAAO7pB+RBgAAACQhF1o=': {'cf:id': 32973,
#                                                    'cf:jiffies': '4294957786',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.2:48036',
#                                                    'cf:seq': 1511465252,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.2:48036->10.5.0.3:8081 '
#                                                                  '(32973)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACDNgQAACgUAAgoFAAO7pB+RBgAAACQhF1s=': {'cf:id': 33229,
#                                                    'cf:jiffies': '4294957786',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.2:48036',
#                                                    'cf:seq': 1528242468,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.2:48036->10.5.0.3:8081 '
#                                                                  '(33229)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACDNggAACgUAAgoFAAO7pB+RBgAAACQhF1s=': {'cf:id': 33485,
#                                                    'cf:jiffies': '4294957796',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.2:48036',
#                                                    'cf:seq': 1528242468,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.2:48036->10.5.0.3:8081 '
#                                                                  '(33485)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACDNgwAACgUAAgoFAAO7pB+RBgAAACQhF68=': {'cf:id': 33741,
#                                                    'cf:jiffies': '4294957796',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.2:48036',
#                                                    'cf:seq': 2937528612,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.2:48036->10.5.0.3:8081 '
#                                                                  '(33741)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACDNhAAACgUAAgoFAAO7pB+RBgAAACQhF68=': {'cf:id': 33997,
#                                                    'cf:jiffies': '4294957796',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.2:48036',
#                                                    'cf:seq': 2937528612,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.2:48036->10.5.0.3:8081 '
#                                                                  '(33997)',
#                                                    'prov:type': 'packet'},
#   'AAAQAAAAACDNhQAACgUAAgoFAAO7pB+RBgAAACQhF68=': {'cf:id': 34253,
#                                                    'cf:jiffies': '4294957808',
#                                                    'cf:receiver': '10.5.0.3:8081',
#                                                    'cf:sender': '10.5.0.2:48036',
#                                                    'cf:seq': 2937528612,
#                                                    'prov:label': '[packet] '
#                                                                  '10.5.0.2:48036->10.5.0.3:8081 '
#                                                                  '(34253)',
#                                                    'prov:type': 'packet'},
#   'AAEAAAAAACAWJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:27',
#                                                    'cf:gid': 50,
#                                                    'cf:id': '75542',
#                                                    'cf:ino': 0,
#                                                    'cf:jiffies': '4294765276',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0x81a4',
#                                                    'cf:secctx': 'system_u:object_r:svirt_sandbox_file_t:s0:c593,c741',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': 'a7e46a51-c3ed-e499-8d6a-3608878665e2',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[file] 0',
#                                                    'prov:type': 'file'},
#   'AAEAAAAAACAZJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:27',
#                                                    'cf:gid': 50,
#                                                    'cf:id': '75545',
#                                                    'cf:ino': 0,
#                                                    'cf:jiffies': '4294765301',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0x81a4',
#                                                    'cf:secctx': 'system_u:object_r:svirt_sandbox_file_t:s0:c593,c741',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': 'a7e46a51-c3ed-e499-8d6a-3608878665e2',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[file] 0',
#                                                    'prov:type': 'file'},
#   'AAEAAAAAACAZJwEAAAAAAIdLGEIqRMJJAQAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:27',
#                                                    'cf:gid': 50,
#                                                    'cf:id': '75545',
#                                                    'cf:ino': 0,
# ...
#   'ACAAAAAAACDqNQEAAAAAAIdLGEIqRMJJAgAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:40',
#                                                    'cf:gid': 0,
#                                                    'cf:id': '79338',
#                                                    'cf:ino': 32424,
#                                                    'cf:jiffies': '4294958946',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0xc1ff',
#                                                    'cf:secctx': 'system_u:object_r:unlabeled_t:s0',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': '77689d19-cdcc-3ae7-9e91-c3bcd55ec46d',
#                                                    'cf:version': 2,
#                                                    'prov:label': '[socket] 2',
#                                                    'prov:type': 'socket'},
#   'ACAAAAAAACDqNQEAAAAAAIdLGEIqRMJJAwAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:40',
#                                                    'cf:gid': 0,
#                                                    'cf:id': '79338',
#                                                    'cf:ino': 32424,
#                                                    'cf:jiffies': '4294958946',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0xc1ff',
#                                                    'cf:secctx': 'system_u:object_r:unlabeled_t:s0',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': '77689d19-cdcc-3ae7-9e91-c3bcd55ec46d',
#                                                    'cf:version': 3,
#                                                    'prov:label': '[socket] 3',
#                                                    'prov:type': 'socket'},
#   'ACAAAAAAACDqNQEAAAAAAIdLGEIqRMJJBAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:40',
#                                                    'cf:gid': 0,
#                                                    'cf:id': '79338',
#                                                    'cf:ino': 32424,
#                                                    'cf:jiffies': '4294958946',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0xc1ff',
#                                                    'cf:secctx': 'system_u:object_r:unlabeled_t:s0',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': '77689d19-cdcc-3ae7-9e91-c3bcd55ec46d',
#                                                    'cf:version': 4,
#                                                    'prov:label': '[socket] 4',
#                                                    'prov:type': 'socket'},
#   'AEAAAAAAACAhJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:27',
#                                                    'cf:gid': 50,
#                                                    'cf:id': '75553',
#                                                    'cf:ino': 0,
#                                                    'cf:jiffies': '4294765306',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0x81ed',
#                                                    'cf:secctx': 'system_u:object_r:unlabeled_t:s0',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': 'a7e46a51-c3ed-e499-8d6a-3608878665e2',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[mmaped_file] '
#                                                                  '0',
#                                                    'prov:type': 'mmaped_file'},
#   'AEAAAAAAACAiJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:27',
#                                                    'cf:gid': 50,
#                                                    'cf:id': '75554',
#                                                    'cf:ino': 0,
#                                                    'cf:jiffies': '4294765306',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0x81ed',
#                                                    'cf:secctx': 'system_u:object_r:unlabeled_t:s0',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': 'a7e46a51-c3ed-e499-8d6a-3608878665e2',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[mmaped_file] '
#                                                                  '0',
#                                                    'prov:type': 'mmaped_file'},
#   'AEAAAAAAACAqJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:27',
#                                                    'cf:gid': 0,
#                                                    'cf:id': '75562',
#                                                    'cf:ino': 0,
#                                                    'cf:jiffies': '4294765359',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0x81a4',
#                                                    'cf:secctx': 'system_u:object_r:unlabeled_t:s0',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': 'a7e46a51-c3ed-e499-8d6a-3608878665e2',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[mmaped_file] '
#                                                                  '0',
#                                                    'prov:type': 'mmaped_file'},
#   'AEAAAAAAACAwJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:27',
#                                                    'cf:gid': 0,
#                                                    'cf:id': '75568',
#                                                    'cf:ino': 0,
#                                                    'cf:jiffies': '4294765370',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0x81a4',
#                                                    'cf:secctx': 'system_u:object_r:unlabeled_t:s0',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': 'a7e46a51-c3ed-e499-8d6a-3608878665e2',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[mmaped_file] '
#                                                                  '0',
#                                                    'prov:type': 'mmaped_file'},
#   'AEAAAAAAACAxJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:51:27',
#                                                    'cf:gid': 0,
#                                                    'cf:id': '75569',
#                                                    'cf:ino': 0,
#                                                    'cf:jiffies': '4294765370',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0x81a4',
#                                                    'cf:secctx': 'system_u:object_r:unlabeled_t:s0',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': 'a7e46a51-c3ed-e499-8d6a-3608878665e2',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[mmaped_file] '
#                                                                  '0',
#                                                    'prov:type': 'mmaped_file'},
#   'AEAAAAAAACB8NQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:35',
#                                                    'cf:gid': 50,
#                                                    'cf:id': '79228',
#                                                    'cf:ino': 0,
#                                                    'cf:jiffies': '4294954282',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0x81ed',
#                                                    'cf:secctx': 'system_u:object_r:unlabeled_t:s0',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': '804e35f4-59d9-69a4-4125-eecc04fb4f85',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[mmaped_file] '
#                                                                  '0',
#                                                    'prov:type': 'mmaped_file'},
#   'AEAAAAAAACB9NQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:35',
#                                                    'cf:gid': 50,
#                                                    'cf:id': '79229',
#                                                    'cf:ino': 0,
#                                                    'cf:jiffies': '4294954282',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0x81ed',
#                                                    'cf:secctx': 'system_u:object_r:unlabeled_t:s0',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': '804e35f4-59d9-69a4-4125-eecc04fb4f85',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[mmaped_file] '
#                                                                  '0',
#                                                    'prov:type': 'mmaped_file'},
#   'AEAAAAAAACCQNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:39',
#                                                    'cf:gid': 50,
#                                                    'cf:id': '79248',
#                                                    'cf:ino': 0,
#                                                    'cf:jiffies': '4294957786',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0x81ed',
#                                                    'cf:secctx': 'system_u:object_r:unlabeled_t:s0',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': '804e35f4-59d9-69a4-4125-eecc04fb4f85',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[mmaped_file] '
#                                                                  '0',
#                                                    'prov:type': 'mmaped_file'},
#   'AEAAAAAAACCRNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:39',
#                                                    'cf:gid': 50,
#                                                    'cf:id': '79249',
#                                                    'cf:ino': 0,
#                                                    'cf:jiffies': '4294957786',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0x81ed',
#                                                    'cf:secctx': 'system_u:object_r:unlabeled_t:s0',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': '804e35f4-59d9-69a4-4125-eecc04fb4f85',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[mmaped_file] '
#                                                                  '0',
#                                                    'prov:type': 'mmaped_file'},
#   'AEAAAAAAACDmNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:40',
#                                                    'cf:gid': 50,
#                                                    'cf:id': '79334',
#                                                    'cf:ino': 0,
#                                                    'cf:jiffies': '4294958939',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0x81ed',
#                                                    'cf:secctx': 'system_u:object_r:unlabeled_t:s0',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': '804e35f4-59d9-69a4-4125-eecc04fb4f85',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[mmaped_file] '
#                                                                  '0',
#                                                    'prov:type': 'mmaped_file'},
#   'AEAAAAAAACDnNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=': {'cf:boot_id': 1108888455,
#                                                    'cf:date': '2017:02:10T14:54:40',
#                                                    'cf:gid': 50,
#                                                    'cf:id': '79335',
#                                                    'cf:ino': 0,
#                                                    'cf:jiffies': '4294958939',
#                                                    'cf:machine_id': 1237468202,
#                                                    'cf:mode': '0x81ed',
#                                                    'cf:secctx': 'system_u:object_r:unlabeled_t:s0',
#                                                    'cf:uid': 0,
#                                                    'cf:uuid': '804e35f4-59d9-69a4-4125-eecc04fb4f85',
#                                                    'cf:version': 0,
#                                                    'prov:label': '[mmaped_file] '
#                                                                  '0',
#                                                    'prov:type': 'mmaped_file'}}]

# %%
pprint(set([v for v in getAllValuesForKey('prov:entity',d1)]))
# Thomas said this is a combination (perhaps concatenation even) of machine_id, boot_id, 
#    and some other ids that are guaranteed to make it a unique id
# Out:
# {'AAAIAAAAACAXJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAAIAAAAACAsJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAAIAAAAACB2NQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAAIAAAAACCONQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAAIAAAAACDlNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAEAAAAAACAWJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAEAAAAAACAZJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAEAAAAAACAZJwEAAAAAAIdLGEIqRMJJAQAAAAAAAAA=',
#  'AAEAAAAAACAbJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAEAAAAAACAdJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAEAAAAAACAdJwEAAAAAAIdLGEIqRMJJAQAAAAAAAAA=',
#  'AAEAAAAAACAfJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAEAAAAAACAoJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAEAAAAAACAuJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAEAAAAAACAyJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAEAAAAAACB3NQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAEAAAAAACB4NQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAEAAAAAACB6NQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AAEAAAAAACCVHwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'ABAAAAAAACBkIwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'ACAAAAAAACAmJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'ACAAAAAAACB/NQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'ACAAAAAAACB/NQEAAAAAAIdLGEIqRMJJAQAAAAAAAAA=',
#  'ACAAAAAAACB/NQEAAAAAAIdLGEIqRMJJAgAAAAAAAAA=',
#  'ACAAAAAAACB/NQEAAAAAAIdLGEIqRMJJAwAAAAAAAAA=',
#  'ACAAAAAAACB/NQEAAAAAAIdLGEIqRMJJBAAAAAAAAAA=',
#  'ACAAAAAAACBPNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'ACAAAAAAACBPNQEAAAAAAIdLGEIqRMJJAQAAAAAAAAA=',
#  'ACAAAAAAACBPNQEAAAAAAIdLGEIqRMJJAgAAAAAAAAA=',
#  'ACAAAAAAACBPNQEAAAAAAIdLGEIqRMJJAwAAAAAAAAA=',
#  'ACAAAAAAACBPNQEAAAAAAIdLGEIqRMJJBAAAAAAAAAA=',
#  'ACAAAAAAACCSNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'ACAAAAAAACCSNQEAAAAAAIdLGEIqRMJJAQAAAAAAAAA=',
#  'ACAAAAAAACCSNQEAAAAAAIdLGEIqRMJJAgAAAAAAAAA=',
#  'ACAAAAAAACCSNQEAAAAAAIdLGEIqRMJJAwAAAAAAAAA=',
#  'ACAAAAAAACCSNQEAAAAAAIdLGEIqRMJJBAAAAAAAAAA=',
#  'ACAAAAAAACCSNQEAAAAAAIdLGEIqRMJJBQAAAAAAAAA=',
#  'ACAAAAAAACCSNQEAAAAAAIdLGEIqRMJJBgAAAAAAAAA=',
#  'ACAAAAAAACCSNQEAAAAAAIdLGEIqRMJJBwAAAAAAAAA=',
#  'ACAAAAAAACCUNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'ACAAAAAAACCUNQEAAAAAAIdLGEIqRMJJAQAAAAAAAAA=',
#  'ACAAAAAAACCUNQEAAAAAAIdLGEIqRMJJAgAAAAAAAAA=',
#  'ACAAAAAAACCUNQEAAAAAAIdLGEIqRMJJAwAAAAAAAAA=',
#  'ACAAAAAAACCUNQEAAAAAAIdLGEIqRMJJBAAAAAAAAAA=',
#  'ACAAAAAAACDoNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'ACAAAAAAACDoNQEAAAAAAIdLGEIqRMJJAQAAAAAAAAA=',
#  'ACAAAAAAACDoNQEAAAAAAIdLGEIqRMJJAgAAAAAAAAA=',
#  'ACAAAAAAACDoNQEAAAAAAIdLGEIqRMJJAwAAAAAAAAA=',
#  'ACAAAAAAACDoNQEAAAAAAIdLGEIqRMJJBAAAAAAAAAA=',
#  'ACAAAAAAACDoNQEAAAAAAIdLGEIqRMJJBQAAAAAAAAA=',
#  'ACAAAAAAACDoNQEAAAAAAIdLGEIqRMJJBgAAAAAAAAA=',
#  'ACAAAAAAACDqNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'ACAAAAAAACDqNQEAAAAAAIdLGEIqRMJJAQAAAAAAAAA=',
#  'ACAAAAAAACDqNQEAAAAAAIdLGEIqRMJJAgAAAAAAAAA=',
#  'ACAAAAAAACDqNQEAAAAAAIdLGEIqRMJJAwAAAAAAAAA=',
#  'ACAAAAAAACDqNQEAAAAAAIdLGEIqRMJJBAAAAAAAAAA=',
#  'AEAAAAAAACAhJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AEAAAAAAACAiJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AEAAAAAAACAqJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AEAAAAAAACAwJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AEAAAAAAACAxJwEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AEAAAAAAACB8NQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AEAAAAAAACB9NQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AEAAAAAAACCQNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AEAAAAAAACCRNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AEAAAAAAACDmNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=',
#  'AEAAAAAAACDnNQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA='}

# %%
pprint(set([v for v in getAllValuesForKey('type',d1)]))
# Out:
# {'AF_UNIX', 'AF_INET'}

# %%
pprint(set([v for v in getAllValuesForKey('cf:ino',d1)]))
#Observations: cf:ino 
# 32421,32422,32423,32424,32409,31901,31902 correspond to sockets
# 31112 correspond to fifo
# Out:
# {0, 32421, 32422, 32423, 31112, 32424, 32409, 31901, 31902}

# %%
pprint(set([v for v in getAllValuesForKey('cf:gid',d1)]))
# Out:
# {0, 50}

# %%
pprint(set([v for v in getAllValuesForKey('cf:machine_id',d1)]))
pprint(set([v for v in getAllValuesForKey('cf:boot_id',d1)]))
# Nothing interesting here
# Out:
# {1237468202}
# {1108888455}

# %%
pprint(set([v for v in getAllValuesForKey('cf:jiffies',d1)]))
# Out:
# {'4294765090',
#  '4294765276',
#  '4294765277',
#  '4294765298',
#  '4294765299',
#  '4294765301',
#  '4294765302',
#  '4294765305',
#  '4294765306',
#  '4294765349',
#  '4294765350',
#  '4294765359',
#  '4294765370',
#  '4294765371',
#  '4294765378',
#  '4294948641',
#  '4294948645',
#  '4294954243',
#  '4294954256',
#  '4294954258',
#  '4294954261',
#  '4294954262',
#  '4294954264',
#  '4294954266',
#  '4294954282',
#  '4294954293',
#  '4294957782',
#  '4294957786',
#  '4294957796',
#  '4294957797',
#  '4294957808',
#  '4294958939',
#  '4294958946'}

# %%
pprint(set([v for v in getAllValuesForKey('cf:secctx',d1)]))
#This seems key, and Thomas also mentioned this: " It handles SELinux security context, 
#  CGroup and similar things that are used to build "container" 
#  (that do not exist as such in the kernel). 
#  At the minima they are now recorded in the activity/entity data, 
#  and you can setup "filter" based on it. \ie record all provenance from CGroup X, 
#  where the CGroup correspond to your container, or similarly using the security context. "
# Out:
# {'system_u:object_r:svirt_sandbox_file_t:s0:c372,c604',
#  'system_u:object_r:svirt_sandbox_file_t:s0:c593,c741',
#  'system_u:object_r:unlabeled_t:s0',
#  'system_u:system_r:docker_t:s0',
#  'system_u:system_r:svirt_lxc_net_t:s0:c372,c604',
#  'system_u:system_r:svirt_lxc_net_t:s0:c593,c741'}

# %%
dicts = getDictImmediatelyEnclosingKeyValue(key1='cf:secctx',value1='system_u:system_r:svirt_lxc_net_t:s0:c372,c604',nested=d1)
for item in dicts:
    if isinstance(item,dict):
        print(item)
# OK, so, task just might be a sister json dict, and not the parent of cf:secctx, 
#   so i need to tweak the function to get this right. But I can infer something using just good old 
#   search in my text file:
'''
"AQAAAAAAAEDDJQEAAAAAAIdLGEIqRMJJAAAAAAAAAAA=": {
			"cf:id": "75203",
			"prov:type": "task",
			"cf:boot_id": 1108888455,
			"cf:machine_id": 1237468202,
			"cf:version": 0,
			"cf:date": "2017:02:10T14:51:27",
			"cf:jiffies": "4294765090",
			"cf:uid": 0,
			"cf:gid": 0,
			"cf:pid": 2618,
			"cf:vpid": 1,
			"cf:cid": 4026531835,
			"cf:secctx": "system_u:system_r:svirt_lxc_net_t:s0:c372,c604",
			"prov:label": "[task] 0"
		},

"AQAAAAAAAEBmNQEAAAAAAIdLGEIqRMJJAQAAAAAAAAA=": {
			"cf:id": "79206",
			"prov:type": "task",
			"cf:boot_id": 1108888455,
			"cf:machine_id": 1237468202,
			"cf:version": 1,
			"cf:date": "2017:02:10T14:54:35",
			"cf:jiffies": "4294954282",
			"cf:uid": 0,
			"cf:gid": 0,
			"cf:pid": 2850,
			"cf:vpid": 7,
			"cf:cid": 4026531835,
			"cf:secctx": "system_u:system_r:svirt_lxc_net_t:s0:c372,c604",
			"prov:label": "[task] 1"
		},

'''
# Out:
# {'prov:type': 'task'}
# {'prov:type': 'task'}
# {'prov:type': 'task'}
# {'prov:type': 'task'}
# {'prov:type': 'task'}
# {'prov:type': 'task'}
# {'prov:type': 'task'}
# {'prov:type': 'task'}
